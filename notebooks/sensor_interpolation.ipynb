# %%
from saflow.features.utils import create_fnames, segment_sourcelevel
import mne_bids
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import saflow

def get_chan_variance(raw, threshold=1e-24, plot=True):
    data = raw.get_data()
    variances = []
    names = []
    for chan_idx in range(data.shape[0]):
        chan_data = data[chan_idx,:]
        ch_name = raw.info['ch_names'][chan_idx]
        variances.append(np.var(chan_data))
        names.append(ch_name)
    variances = np.array(variances)
    names = np.array(names)
    # Order variances and names by variance
    variances = variances[np.argsort(variances)]
    names = names[np.argsort(variances)]
    # Get the list of channels with variance > threshold
    names_bad_channels = names[variances > threshold]
    variances_bad_channels = variances[variances > threshold]

    if plot:
        plot_df = pd.DataFrame({'variance':variances, 'name':names})
        plot_df.sort_values(by='variance', inplace=True)
        plt.figure(figsize=(20,5))
        sns.barplot(x='name', y='variance', data=plot_df)
        plt.xticks(rotation=90)
        plt.show()
    return {'names':names, 'variances':variances, 'names_bad_channels':names_bad_channels, 'variances_bad_channels':variances_bad_channels}

# %%
bad_channels_list = []
n_bads = []
subj_list = []
run_list = []
for subject in saflow.SUBJ_LIST:
    for run in ['02', '03', '04', '05', '06']:

        filepaths = create_fnames(subject, run)
        raw = mne_bids.read_raw_bids(filepaths['preproc'], verbose=False)
        raw_mag = raw.copy().pick_types(meg=True, ref_meg=False, eeg=False, eog=False)
        data = raw_mag.get_data()

        variances_dict = get_chan_variance(raw_mag, threshold=1e-23)
        bad_channels_list.append(len(variances_dict['names_bad_channels']))
        n_bads.append(len(variances_dict['names_bad_channels']))
        subj_list.append(subject)
        run_list.append(run)
        print(f'Bad channels for subject {subject} run {run}:')
        print(variances_dict['names_bad_channels'])
        
plot_df = pd.DataFrame({'n_bads':n_bads, 'subj':subj_list, 'run':run_list})
plt.figure(figsize=(20,5))
sns.barplot(x='subj', y='n_bads', hue='run', data=plot_df)
    #plt.title(f'Run {run}')
# Out:
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 04 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 04 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 04 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 04 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 04 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 05 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 05 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 05 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 05 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 05 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 06 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 06 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 06 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 06 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# /tmp/ipykernel_10907/259851125.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(20,5))
# Bad channels for subject 06 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 07 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 07 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 07 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 07 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 07 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 08 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 08 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 08 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 08 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 08 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 09 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 09 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 09 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 09 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 09 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 10 run 02:
# ['MZO01-3105' 'MZO02-3105' 'MZO03-3105' 'MZP01-3105']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 10 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 10 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 10 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 10 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 11 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 11 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 11 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 11 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 11 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 12 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 12 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 12 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 12 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 12 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 13 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 13 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 13 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 13 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 13 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 14 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 14 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 14 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 14 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 14 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 15 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 15 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 15 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 15 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 15 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 17 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 17 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 17 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 17 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 17 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 18 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 18 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 18 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 18 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 18 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 19 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 19 run 03:
# ['MZO01-3105' 'MZO02-3105' 'MZO03-3105' 'MZP01-3105']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 19 run 04:
# ['MZO01-3105' 'MZO02-3105' 'MZO03-3105' 'MZP01-3105']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 19 run 05:
# ['MZF03-3105' 'MZO01-3105' 'MZO02-3105' 'MZO03-3105' 'MZP01-3105']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 19 run 06:
# ['MZP01-3105']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 20 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 20 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 20 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 20 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 20 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 21 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 21 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 21 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 21 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 21 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 22 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 22 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 22 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 22 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 22 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 23 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 23 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 23 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 23 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 23 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 24 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 24 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 24 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 24 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 24 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 26 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 26 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 26 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 26 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 26 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 28 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 28 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 28 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 28 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 28 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 29 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 29 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 29 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 29 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 29 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 30 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 30 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 30 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 30 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 30 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 31 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 31 run 03:
# ['MZF01-3105' 'MZF02-3105' 'MZF03-3105' 'MZO01-3105' 'MZO02-3105'
#  'MZO03-3105' 'MZP01-3105']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 31 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 31 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 31 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 32 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 32 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 32 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 32 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 32 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 33 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 33 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 33 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 33 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 33 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 34 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 34 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 34 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 34 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 34 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 35 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 35 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 35 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 35 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 35 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 36 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 36 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 36 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 36 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 36 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 37 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 37 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 37 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 37 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 37 run 06:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 38 run 02:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 38 run 03:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 38 run 04:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 38 run 05:
# []
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing 5 compensators from info because not all compensation channels were picked.
# Bad channels for subject 38 run 06:
# []
# <Axes: xlabel='subj', ylabel='n_bads'>
